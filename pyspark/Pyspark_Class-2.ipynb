# %%
trips_df = spark.table("samples.nyctaxi.trips")
display(trips_df)
trips_df.show()

# %%
#import pyspark functions
from pyspark.sql import functions as F

# %%
trips_df = trips_df1
display(trips_df1)

# %%
trips_df = trips_df.select(F.col("trip_distance"), F.col("fare_amount"))
display(trips_df)

# %%
#display(trips_df)
#display(trips_df1)
trips_df = trips_df1

# %%
trips_df = trips_df.withColumn("fare_amount_inr",F.col("fare_amount")*92)
display(trips_df)

# %%
trip_df = trips_df.withColumn("dummy2",F.lit("Mk"))
display(trip_df)

# %%
#Creating multiple columns with withColumn()
trip_df = (trips_df
.withColumn("dummy3",F.lit("sMk"))
.withColumn("dummy4",F.lit("Mks100"))
)
            
display(trip_df)

# %%
#converting columns to another data type.
trip_df = trip_df.withColumn("pickup_zip",F.col("pickup_zip").cast("string"))
display(trip_df)

# %%
#Cast multiple columns

trip_df = (
    trip_df
    .withColumn("pickup_zip",F.col("pickup_zip").cast("int"))
    .withColumn("dropoff_zip",F.col("dropoff_zip").cast("string"))
)
display(trip_df)

# %%
# changes a column name. 
trip_df = trip_df.withColumnRenamed("fare_amount_inr","fare_amount_Rupee")
display(trip_df)

# %%
# %sql


SELECT * FROM samples.nyctaxi.trips

# %%
# spark.sql() allows you to execute SQL from Python.
df=spark.sql("SELECT * FROM samples.nyctaxi.trips")
display(df)

# %%
# spark.table() Reads the table.
df=spark.table("samples.nyctaxi.trips")
display(df)

# %%
# DataFrame select() method-1

df = df.select("trip_distance","fare_amount")
display(df)

# %%
# DataFrame select() method-2

df = df.select(df.trip_distance,df.fare_amount)
display(df)

# %%
# DataFrame select() method-3

df = df.select(df["trip_distance"],df["fare_amount"])
display(df)

# %%
# DataFrame select() using F.col() method-4

df = df.select(F.col("trip_distance"),F.col("fare_amount"))
display(df)

# %%
# alias()
tripss_df= trip_df.select(F.col("fare_amount").alias("Murali"))
display(tripss_df)

# %%
# %sql
-- select top(10)* FROM samples.nyctaxi.trips  --not working
select * FROM samples.nyctaxi.trips limit 9

# %%
# DataFrame limit() --limit() returns a DataFrame.
df = trip_df.limit(10)
display(df)

# %%
# DataFrame head() --head() returns a list of Row objects
df = trip_df.head(10)
display(df)

# %%
# DataFrame tail() --tail() returns a list of Row objects
df = trip_df.tail(10)
display(df)

# %%
# printSchema()  Displays the DataFrame schema.
trip_df.printSchema()

# %%
# Schema()  Displays the DataFrame schema
print(trip_df.schema)

# %%
# count()
count = trips_df.count()
print(count)

# %%
# columns
columns=trip_df.columns
display(columns)

# %%
# describe() Provides basic statistical information.like count,mean,stddev,min,max etc
trips_df.describe().show()

# %%
# collect() Collects all rows from the Spark DataFrame to the driver.
rows = trips_df.collect()

# %%
trips_df.first()

# %%
# Returns the first 5 rows as a list of Row objects.?
trips_df.take(5)

# %%
trips_df.rdd.getNumPartitions()

# %%
pd_df = trips_df.toPandas()
