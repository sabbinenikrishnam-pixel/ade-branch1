# %%
print("hello murali")

# %%
#Dataframes

# %%
emp_data= [
    (101,'Murali',2000),
    (102,'Ravi',3000),
    (103,'Rajesh',4000),
    (104,'Rakesh',5000)
]

emp_cols=['empid','ename','salary']
emp_df=spark.createDataFrame(data=emp_data,schema=emp_cols)
display(emp_df)
# Out:
# Databricks data profile. Run in Databricks to view.

# %%
emp_df.show()

# %%
from pyspark.sql import functions as F
from pyspark.sql.types import StructType,StructField,StringType,IntegerType

stu_data=[
    (100,'Murali',1,'A'),
    (101,'Ravi',2,'B'),
    (102,'Rajesh',3,'C'),
    (103,'Rakesh',4,'C'),
    (104,'Rakesh',5,'C')
]

schema=StructType([
    StructField('stuid',IntegerType(),False),
    StructField('stuname',StringType()),
    StructField('rollno',IntegerType()),
    StructField('section',StringType())
])

stu_df = spark.createDataFrame(data=stu_data,schema=schema)
display(stu_df)

# %%
stu_df.rdd.getNumPartitions()

# %%
df= spark.table("samples.nyctaxi.trips")
df.count()

# %%
df.rdd.getNumPartitions()  # Not supported in serverless mode, consider using df.repartition(n).getNumPartitions() if repartitioning is needed.
